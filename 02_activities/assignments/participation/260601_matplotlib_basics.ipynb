# %% [markdown]
# # Lecture 1: Matplotlib Basics
#
# This notebook contains the live coding activities from the June 1 data visualization class.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.scatter(x, y)

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.bar(x, y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot(x, y)

# %% [markdown]
# Histogram Activity
#
# The histogram displays the frequency distribution of the y values, so only the y variable is required.

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Adding Titles and Axis Labels

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot(x, y) 
ax.set_title("Total growth over time") 
ax.set_ylabel("Total growth") 
ax.set_xlabel("Years since start") 
fig.tight_layout()

# %% [markdown]
# Customizing Fonts

# %%
font1 = { "family": "sans-serif", "color": "blue", "size": 20, } 
font2 = { "family": "monospace", "color": "green", "size": 14, }

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot(x, y) 
ax.set_title( "Total growth over time", fontdict=font1, ) 
ax.set_ylabel( "Total growth", fontdict=font2, ) 
ax.set_xlabel( "Years since start", fontdict=font2, ) 
fig.tight_layout()

# %% [markdown]
# Moving the Title

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot(x, y) 
ax.set_title( "Total growth over time", fontdict=font1, loc="left", ) 
ax.set_ylabel( "Total growth", fontdict=font2, ) 
ax.set_xlabel( "Years since start", fontdict=font2, )
fig.tight_layout()

# %% [markdown]
# Customizing Markers and Colour

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.scatter( x, y, marker="*", color="indigo", )

# %% [markdown]
# Customizing Line Style and Width

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot( x, y, marker="*", color="indigo", linestyle="--", linewidth=2, )

# %% [markdown]
# Using Hex Colours

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot( x, y, marker="*", color="#7425b9", linestyle="--", linewidth=2, )

# %% [markdown]
# Marker Size, Edge Colour, and Face Colour

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot( x, y, marker="*", markersize=12, color="#7425b9", linestyle="--", linewidth=2, markeredgecolor="#fa9359", markerfacecolor="#000000", )

# %% [markdown]
# Basic Grid Lines

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot(x, y) 
ax.grid(axis="y")

# %% [markdown]
# Grid-Line Customization Activity
#
# For this activity, I customized the horizontal grid lines by changing their colour, width, and line style.

# %%
fig, ax = plt.subplots(figsize=(5, 3)) 
ax.plot( x, y, marker="*", color="#7425b9", linestyle="--", linewidth=2, ) 
ax.grid( axis="y", color="blue", linewidth=2, linestyle="-.", )

# %% [markdown]
# In this class, I learned how to create scatter plots, bar plots, line plots, and histograms; add titles and axis labels; customize fonts and title placement; modify marker shapes, sizes, and colours; change line style and width; use named colours and hexadecimal colour codes;
# add and customize grid lines.
